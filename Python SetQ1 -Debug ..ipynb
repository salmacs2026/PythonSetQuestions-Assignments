# %%
#1.Find the error in the following Python code:

    #for i in range(5)
    #print(i)

for i in range(5):    # Missing Colon
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?
    #a = 10
    #b = "5"
    #print(a + b)

a = 10
b = "5"
print(a +int(b))    # Convert string into integer
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

    #def add_numbers(a, b)
    #return a + b

def add_numbers(a, b):    # Missing Colon
    return a + b

# %%
#4.Identify the bug in the following Python code:

    #numbers = [1, 2, 3, 4]
    #print(numbers[4])

numbers = [1, 2, 3, 4]
print(numbers)    # Index Error
# Out:
# [1, 2, 3, 4]

# %%
#5.Find the error in the following Python code:

    #print "Hello, World!"

print ("Hello, World!")    # Missing Paranthesis
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:

    #x = 5 / 0

x=5    # Can't divisible by zero

# %%
#7.Find the error in the following Python code:name = "Alice"

    #age = 25
    #print("Name: " + name + ", Age: " + age)

name="Alice"                            # Misiing Name Declaration
age = 25
print("Name:",name , "Age:" + str(age)) # Concatenate integer into string
# Out:
# Name: Alice Age:25

# %%
#8.Find the error
    
    #for i in range(1, 10, -1):
    #print(i)

for i in range(10, 1, -1):    # Changed Start and Stop Values
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
    
    #x = 10
    #if x = 5:
    #print("x is 5")

x = 10
if x == 5:            # Asssigned Operator used instead of Comparison Operator
    print("x is 5")

# %%
#10. Identify the error in the following function definition:
    
    #def greet(name)
    #print("Hello, " + name)

def greet(name):            # Colon missing
    print("Hello, " + name)
