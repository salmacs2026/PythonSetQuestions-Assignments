# %%
#1.Find the error in the following Python code:
import math

print(Math.sqrt(16)) # Case -sensitive

# %%
#Answer:

import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

def my_function():  # x not declared in the function
    x += 5
    print(x)

x = 10
my_function()       # x not declared in the function

# %%
#Answer:

def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x)
# Out:
# 15

# %%
#3.x = 5

if x = 10:           # assignment operator used instead of comparison operator
    print("x is 10")

# %%
#Answer:

if x == 10:        
    print("x is 10")
# Out:
# x is 10

# %%
#4.

numbers = [5, 3, 8, 2]   # Missing Condition
print(numbers.sort())    # Variable not Called

# %%
#Answer:

numbers = [5, 3, 8, 2]
numbers.sort()   
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.

def square(n):
    n * n

print(square(4))

# %%
#Answer:

def square(n):
    return n * n   #Values not returned
print(square(4))
# Out:
# 16

# %%
#6.

my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
#Answer:

my_list = [1, 2, 3]  # Tuples are immutable
my_list[1] = 5
print(my_list)
# Out:
# [1, 5, 3]

# %%
#7.

name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
#Answer:

name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age)) #variable age not declared
# Out:
# My name is Alice and I am 25 years old

# %%
#8.

a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
#Answer:

a = list[1, 2, 3]
b = list[1, 2, 3]
 
if a == b:            #  Use Comparison Operator
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.

for i in range(5, 1):     # Start should smaller than stop
    print(i)

# %%
#Answer:

for i in range(1,5): 
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.

student = {"name": "John", "age": 20}
print(student[name])         # name not declared as variable

# %%
#Answer:

student = {"name": "John", "age": 20}
print(student)
# Out:
# {'name': 'John', 'age': 20}
